# %%
import datetime as dt
import matplotlib.pyplot as plt
from matplotlib import style
import pandas as pd
import pandas_datareader.data as web

# %%
style.use('ggplot')

start = dt.datetime(2020,1,1)
end = dt.datetime.now()

# %%
df = web.DataReader("TSLA", 'yahoo', start, end)

# %%
print(df.head())
# Out:
#         Date        High         Low        Open       Close    Volume  \
# 0 2019-12-31  421.290009  402.079987  405.000000  418.329987  10285700
# 1 2020-01-02  430.700012  421.709991  424.500000  430.260010   9532100
# 2 2020-01-03  454.000000  436.920013  440.500000  443.010010  17778500
# 3 2020-01-06  451.559998  440.000000  440.470001  451.540009  10133000
# 4 2020-01-07  471.630005  453.359985  461.399994  469.059998  17882100
#
#     Adj Close
# 0  418.329987
# 1  430.260010
# 2  443.010010
# 3  451.540009
# 4  469.059998

# %%
df.reset_index(inplace=True)
df.set_index("Date", inplace=True)


print(df.head())
# Out:
#             level_0  index        High         Low        Open       Close  \
# Date
# 2019-12-31        0      0  421.290009  402.079987  405.000000  418.329987
# 2020-01-02        1      1  430.700012  421.709991  424.500000  430.260010
# 2020-01-03        2      2  454.000000  436.920013  440.500000  443.010010
# 2020-01-06        3      3  451.559998  440.000000  440.470001  451.540009
# 2020-01-07        4      4  471.630005  453.359985  461.399994  469.059998
#
#               Volume   Adj Close
# Date
# 2019-12-31  10285700  418.329987
# 2020-01-02   9532100  430.260010
# 2020-01-03  17778500  443.010010
# 2020-01-06  10133000  451.540009
# 2020-01-07  17882100  469.059998

# %%
df.to_csv('TSLA.csv')

# %%
df = pd.read_csv('tsla.csv', parse_dates=True, index_col=0)

# %%
df.plot()
plt.show()

# %%
df['Adj Close'].plot()
plt.show()

# %%
df[['High','Low']]
# Out:
#                   High         Low
# Date
# 2019-12-31  421.290009  402.079987
# 2020-01-02  430.700012  421.709991
# 2020-01-03  454.000000  436.920013
# 2020-01-06  451.559998  440.000000
# 2020-01-07  471.630005  453.359985
# ...                ...         ...
# 2020-05-22  831.780029  812.000000
# 2020-05-26  834.599976  815.710022
# 2020-05-27  827.710022  785.000000
# 2020-05-28  824.750000  801.690002
# 2020-05-29  835.000000  804.210022
#
# [104 rows x 2 columns]
